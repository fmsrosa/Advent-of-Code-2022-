# %% [markdown]
# # Challenge 1

# %%
with open('input/2022_12_07_input') as file:
    f = file.read()
    


_list = f.splitlines()

_list = [ele for ele in _list if ele not in {'$ ls', '$ cd ..'}]


enter_dir_ids = [i for i,val in enumerate(_list) if '$ cd' in val]
_dict = {}
for id1 in range(0, len(enter_dir_ids)-1):
    list2 = []
    sums = 0
    for id2 in range(enter_dir_ids[id1]+1,enter_dir_ids[id1+1]):
        a = _list[id2].split()
        if a[0] == 'dir':
            list2.append(a[1])
        else:
            sums = sums + int(a[0])
    list2.append(sums)
	
    name = _list[enter_dir_ids[id1]].split()[-1]
    _dict[name] = list2
    
for key, value in _dict.items():  
    sums = 0
    while len(_dict[key]) > 1:
        print(1, _dict[key])
        for x in _dict[key]:
            if type(x) == str:
                _dict[key].remove(x)
                if x in _dict.keys():
                	_dict[key] = _dict[key] + _dict[x]
                elif type(x) == int:
                    sums = sums + x
                else:    
                    _dict[key] = _dict[key] 

            else:
                sums = sums + x 
        value[-1] = sums
sums = 0
for key, value in _dict.items():
    #print(key, value)
    if value[-1] <= 100000:
        sums = sums + value[0] 

#print(sums)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# [0, 860600, 488979, 654954, 0, 736226, 224079, 124395, 761668, 0, 168617, 523625, 311933, 196215, 75864, 316034, 235444, 654954, 206593, 0, 449373, 320367, 502684, 755753, 178974, 600713, 63747, 4031, 271528, 62412, 582554, 0, 85635, 62412, 0, 0, 0, 168617, 523625, 261548, 188232, 0, 189996, 62412, 505449, 0, 0, 210083, 466209, 182115, 56989, 110034, 832759, 0, 96177, 181016, 56989, 110034, 832759, 4031, 271528, 174135, 416793, 502684, 0, 67518, 0, 261548, 43005, 261548, 188232, 43005, 0, 62412, 261548, 188232, 9294, 256017, 188232, 0, 0, 9294, 261548, 188232, 256017]
# ...

# %%
f = '''$ cd /
$ ls
dir a
14848514 b.txt
8504156 c.dat
dir d
$ cd a
$ ls
dir e
29116 f
2557 g
62596 h.lst
$ cd e
$ ls
584 i
$ cd ..
$ cd ..
$ cd d
$ ls
4060174 j
8033020 d.log
5626152 d.ext
7214296 k'''

with open('input/2022_12_07_input') as file:
    f = file.read()

_list = f.splitlines()

_list = [ele for ele in _list if ele not in {'$ ls', '$ cd ..'}]


enter_dir_ids = [i for i,val in enumerate(_list) if '$ cd' in val]
_dict = {}
for id1 in range(0, len(enter_dir_ids)):
    list2 = []
    sums = 0
    if id1 != len(enter_dir_ids) - 1:
        last = enter_dir_ids[id1+1]
    else:
        last = len(_list)
    for id2 in range(enter_dir_ids[id1]+1,last):
        a = _list[id2].split()
        if a[0] == 'dir':
            list2.append(a[1])
        else:
            sums = sums + int(a[0])
    list2.append(sums)
	
    name = _list[enter_dir_ids[id1]].split()[-1]
    _dict[name] = list2

for key, value in _dict.items():  
    sums = 0
    while len(value) > 1:
        print(key, value)
        for x in value:
            print('x', x)
            if type(x) == str:
                value.remove(x)
                print('value', value)
                if x in _dict.keys():
                	_dict[key] = value + _dict[x]
                elif type(x) == int:
                    sums = sums + x
                else:    
                    _dict[key] = value 

            else:
                sums = sums + x 
        value[-1] = sums

print(_dict)
sums = 0
for key, value in _dict.items():
    if sum(value[-1]) <= 100000:
        sums = sums + sum(value[-1])

print(sums)
# Out:
# / ['gqcclj', 'lmtpm', 'nhqwt', 'qcq', 'vwqwlqrt', 0]
# x gqcclj
# value ['lmtpm', 'nhqwt', 'qcq', 'vwqwlqrt', 0]
# x nhqwt
# value ['lmtpm', 'qcq', 'vwqwlqrt', 0]
# x vwqwlqrt
# value ['lmtpm', 'qcq', 0]
# / ['lmtpm', 'qcq', 0]
# x lmtpm
# value ['qcq', 0]
# x 0
# / ['qcq', 0]
# x qcq
# value [0]
# lmtpm ['clffsvcw', 'dcqnblb', 'dtpwln', 'fvt', 'hrcrw', 'jdqzmqn', 'qcq', 'rsn', 'zprprf', 736226]
# x clffsvcw
# value ['dcqnblb', 'dtpwln', 'fvt', 'hrcrw', 'jdqzmqn', 'qcq', 'rsn', 'zprprf', 736226]
# x dtpwln
# value ['dcqnblb', 'fvt', 'hrcrw', 'jdqzmqn', 'qcq', 'rsn', 'zprprf', 736226]
# x hrcrw
# value ['dcqnblb', 'fvt', 'jdqzmqn', 'qcq', 'rsn', 'zprprf', 736226]
# x qcq
# value ['dcqnblb', 'fvt', 'jdqzmqn', 'rsn', 'zprprf', 736226]
# x zprprf
# value ['dcqnblb', 'fvt', 'jdqzmqn', 'rsn', 736226]
# lmtpm ['dcqnblb', 'fvt', 'jdqzmqn', 'rsn', 0]
# x dcqnblb
# value ['fvt', 'jdqzmqn', 'rsn', 0]
# x jdqzmqn
# value ['fvt', 'rsn', 0]
# x 0
# lmtpm ['fvt', 'rsn', 0]
# x fvt
# ...

# %%
f = '''$ cd /
$ ls
dir a
14848514 b.txt
8504156 c.dat
dir d
$ cd a
$ ls
dir e
29116 f
2557 g
62596 h.lst
$ cd e
$ ls
584 i
$ cd ..
$ cd ..
$ cd d
$ ls
4060174 j
8033020 d.log
5626152 d.ext
7214296 k'''

with open('input/2022_12_07_input') as file:
    f = file.read()

_list = f.splitlines()

_list = [ele for ele in _list if ele not in {'$ ls', '$ cd ..'}]


enter_dir_ids = [i for i,val in enumerate(_list) if '$ cd' in val]
_dict = {}
for id1 in range(0, len(enter_dir_ids)):
    list2 = []
    sums = 0
    if id1 != len(enter_dir_ids) - 1:
        last = enter_dir_ids[id1+1]
    else:
        last = len(_list)
    for id2 in range(enter_dir_ids[id1]+1,last):
        a = _list[id2].split()
        if a[0] == 'dir':
            list2.append(a[1])
        else:
            sums = sums + int(a[0])
    list2.append(sums)
	
    name = _list[enter_dir_ids[id1]].split()[-1]
    _dict[name] = list2
    
    
_dict
# Out:
# {'/': ['gqcclj', 'lmtpm', 'nhqwt', 'qcq', 'vwqwlqrt', 0],
#  'gqcclj': [860600],
#  'lmtpm': ['clffsvcw',
#   'dcqnblb',
#   'dtpwln',
#   'fvt',
#   'hrcrw',
#   'jdqzmqn',
#   'qcq',
#   'rsn',
#   'zprprf',
#   736226],
#  'clffsvcw': [311933],
#  'dcqnblb': ['zprprf', 62412],
#  'zpswzfvg': [206998],
#  'gfn': [277530],
#  'lpswsp': [173180],
#  'lvt': ['hjllwsvl', 'ptbt', 0],
#  'hjllwsvl': ['wqnc', 0],
#  'wqnc': [64695],
#  'ptbt': [150880],
#  'zprprf': ['bqnpsl', 'dszrvpzc', 0],
#  'ldzslndn': ['bgnhd', 'pgvcdzwz', 'qgzhm', 0],
#  'bwqqsbhg': [108701],
#  'qftt': [64268],
#  'dtpwln': ['dpwg', 'ldzslndn', 'znnsqqh', 196215],
#  'dpwg': ['pbmf', 'rmpvj', 'scgc', 582554],
#  'pbmf': [210083],
#  'rmpvj': [466209],
#  'scgc': [182115],
#  'znnsqqh': [85635],
#  'fvt': ['dcqnblb', 'gnc', 75864],
#  'lbnflwsh': [76197],
#  'gnc': ['jhjbjsp', 'jjppr', 0],
#  'jhjbjsp': [96177],
#  'jjppr': [181016],
#  'hrcrw': [316034],
#  'jdqzmqn': ['ldzslndn', 235444],
# ...

# %%
for key, value in _dict.items():  
    sums = 0
    while len(value) > 1:
        for x in value:
            if type(x) == str:
                value.remove(x)
                if x in _dict.keys():
                	_dict[key] = value + _dict[x]
                elif type(x) == int:
                    sums = sums + x
                else:    
                    _dict[key] = value 

            else:
                sums = sums + x 
        value[-1] = sums
    

print(_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [218], in <cell line: 1>()
#      12                     _dict[key] = value
#      14             else:
# ---> 15                 sums = sums + x
#      16         value[-1] = sums
#      19 print(_dict)
#
# KeyboardInterrupt:
