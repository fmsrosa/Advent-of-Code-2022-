# %% [markdown]
# # Challenge 1

# %%
with open ('input/2022_12_06_input') as file:
    f = file.read()

found = False

count = 4
while found is False:
    candidate = f[0:4]
    if len(set(candidate)) == 4:
        found = True
    else:
        count = count + 1
        f = f[1:]

print(count)
# Out:
# 1953
